# %% [markdown]
# # Redictado de Taller de Lenguajes Python
# ## Segundo Semestre 2026 (UNLP)
# ![](imagenes/marca-50-Anos-del-Golpe.png)
#
# ## Clase 2: Colecciones, funciones y módulos

# %% [markdown]
# ## Valor máximo
# * Los condicionales simples puede ser reescritos de otra forma

# %%
number1 = int(input("Ingresá un número: "))
number2 = int(input("Ingresá un número: "))
if number1 > number2:
    number_max = number1
else:
    number_max = number2   
number_max

# %% [markdown]
# # Expresión condicional
#
# - La forma general es:
#
# ```python
# A if C else B
# ```
# - Devuelve A si se cumple la condición C, sino devuelve B.

# %%
number1 = int(input("Ingresá un número: "))
number2 = int(input("Ingresá un número: "))

number_max = number1 if number1 > number2 else number2 
number_max

# %% [markdown]
# ¿qué otra forma hay más sencilla para saber el valor máximo?

# %% [markdown]
# # No solamente con asignación:

# %%
for i in range(4):
    word = input("Ingresá una palabra: ")
    print("TIENE R" if "r" in word else "NO TIENE R")

# %% [markdown]
# # Evaluación  del condicional
#
# **IMPORTANTE:** Python utiliza la <span style="color:#cd7815">**evaluación con circuito corto**</span> para evaluar las condiciones

# %%
number1 = 1
number2 = 0

if True or number1/number2:
    print("No hay error!!!!???")

# %% [markdown]
# # Películas argentinas
# > Vamos a trabajar con las **películas argentinas candidatas al premio Oscar a mejor película extranjera**.
#
# Queremos saber:
# - ¿Cuál fue la duración promedio, en minutos, de todas las películas?
# - ¿Cuántas películas duran más que el promedio, en minutos?

# %% [markdown]
# Datos según **ChatGPT**:
# ```
# Año de la ceremonia, Película, Resultado, Duración (minutos)
# 1975, La tregua, Nominada, 108
# 1985, Camila, Nominada, 105
# 1986, La historia oficial, Ganadora, 112
# 1999, Tango, no me dejes nunca, Nominada, 115
# 2002, El hijo de la novia, Nominada, 123
# 2010, El secreto de sus ojos, Ganadora, 129
# 2015, Relatos salvajes, Nominada, 122
# 2023, Argentina, 1985, Nominada, 140
# ```

# %% [markdown]
# ¿Cómo sería un pseudocódigo de esto?
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```
# ¿Qué estructura usar en caso de ingreso de datos sin saber la cantidad exacta?

# %% [markdown]
# #  🎒 while: Iteración condicional
#
# - Python tiene una <span style="color:#cd7815">sentencia **while**</span>. Ya la vimos en algunos ejemplos:

# %%
## Adivina adivinador....
import random

random_number = random.randrange(5)
i_won = False
print("Tenés 2 intentos para adivinar un entre 0 y 4")
tries = 1

while tries < 3 and not i_won:
    entered_number = int(input("Ingresa tu número: "))
    if entered_number == random_number:
        print("Ganaste!")
        i_won = True
    else:
        print("Mmmm ... No.. ese número no es... Seguí intentando.")
        tries += 1
if not i_won:
    print("Perdiste :(")
    print(f"El número era: {random_number}")

# %% [markdown]
# ## Sintaxis:
#
# ```python
# while condition:
#     sentence
#     sentence
#
# ```

# %% [markdown]
# Nuestro problema inicial:
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```

# %% [markdown]
# ¿Cómo hacemos el **tercer** proceso? ¿Tenemos que ingresar las duraciones nuevamente?

# %% [markdown]
# Obviamente no. **Necesitamos tipos de datos que nos permitan guardar muchos valores**.

# %% [markdown]
# # 🐍 Colecciones de datos en Python

# %% [markdown]
# <table style="font-size: 60px; width: 100%;">
# <tr>
#     <th>🎒 Listas</th>
#     <th>🎒 Tuplas</th>
#
# </tr>
# <tr>
#     <th>🎒 Conjuntos</th>
#     <th>🎒 Diccionarios</th>
#
# </tr>
#
# </table>

# %% [markdown]
# # 🎒 Listas
#
#
# > <span style="color:#cd7815">Una **lista** es una colección ordenada de elementos.</span>

# %%
movies_duration = [108, 105, 112, 115, 123, 129, 122, 140]

type(movies_duration)

# %% [markdown]
# > Las listas son estructuras <span style="color:#cd7815">heterogéneas</span>, es decir que **pueden contener cualquier tipo de datos**, inclusive otras listas.

# %%
my_list = [1, "dos", [3, "cuatro"], True]
my_list

# %% [markdown]
#  ## ¿Se acuerdan de este método de <span style="color:#cd7815">**str**</span>?

# %%
my_list = "Somos campeones del  mundo!!!".split()
my_list

# %% [markdown]
# <span style="color:#cd7815">El **método split**, retorna una **lista** </span>con los elementos de la cadena de caracteres.

# %% [markdown]
# ## 🔧 Operaciones básicas:
# * **len**(my_list).
# * elem **in** my_list: permite saber si un lemento está en la lista.
# * Las listas se pueden concatenar (**+**) y repetir **(*)**.
# * **append()**: agregar un elemento
# * **pop()**: elimino un elemento

# %% [markdown]
# ## Accediendo a los elementos de una lista
#
# - Se accede a través de **un índice** que indica la posición del elemento dentro de la lista **encerrado entre corchetes** [].
# - **IMPORTANTE:** al igual que las cadenas los índices comienzan en 0.

# %%
my_list = [ 17, "hola", [1, "dos"], 5.5, True] 
my_list[0]

# %% [markdown]
# ¿Cuántos elementos tiene la lista?

# %%
len(my_list)

# %% [markdown]
# ### ¿Cómo agrego un elemento?
#
# Una forma:

# %%
my_list.append("NUEVO")
my_list

# %% [markdown]
# ### ¿Cómo elimino un elemento?
#
# Una forma:

# %%
my_list.pop(1)
my_list

# %% [markdown]
# **Las listas son datos MUTABLES.** ¿Qué quiere decir esto?

# %%
my_list = [12, 2022]

# %%
my_list[0] = [18, 12]
my_list

# %% [markdown]
# ¿Qué cantidad de elementos tiene ahora **my_list**?

# %%
len(my_list)

# %% [markdown]
# # Recorriendo una lista
#
# - ⏩¿Qué estructura les parece que podríamos usar?

# %%
for elem in my_list:
    print(elem)

# %% [markdown]
# ## Podríamos pensar en otra forma de recorrer la lista

# %%
list_len = len(my_list)
for i in range(list_len):
    print(my_list[i])

# %% [markdown]
# ¿Por qué no **range(list_len - 1)**?

# %% [markdown]
# ## Copia de listas
# Observemos el siguiente ejemplo:

# %%
cientificas = ["Cecilia Berdichevsky", "Noemí García", "Julieta Lanteri"]
mujeres = cientificas
cientificas[0] = "Jeanette Campbell"

# %% [markdown]
# ⏩ ¿Cuál es el primer elemento de la lista **mujeres**?

# %%
print(mujeres)

# %% [markdown]
# - Recordemos que las variables son **referencias a objetos**.

# %% [markdown]
# - Cada objeto tiene un identificación.

# %%
#mujeres = cientificas
print(id(mujeres))
print(id(cientificas))

# %%
cientificas.append("Mary Terán")
mujeres

# %% [markdown]
# ## ⏩ Comparamos otras formas de copiar listas

# %%
mas_mujeres = cientificas[:]

# %%
otras_cientificas = cientificas.copy()

# %% [markdown]
# ¿Cuáles tienen el mismo id?

# %% [markdown]
# ## Algunos métodos de las listas:
# *  **append()**: agrega un solo elemento al final de la lista.
# *  **extend()**: agrega todos los elementos de un iterable (lista, tupla, etc.) al final de la lista.
# * **index()**:  devuelve el índice de la primera aparición del elemento especificado.
# * **remove()**:  elimina la **primera** aparición del elemento especificado.
# * **count()**: cuenta cuántas veces aparece un elemento en la lista.
# * [+Info](https://docs.python.org/es/3/tutorial/datastructures.html) en la documentación oficial.

# %% [markdown]
# # Algunas cosas para <span style="color:#cd7815">prestar atención</span>
#
# Analicemos el siguiente código:

# %%
strange_list = [1, "dos", [3, "cuatro"]]
list1 = strange_list.copy() 
list2 = strange_list[:]

# %% [markdown]
# ¿Qué pasa con la lista original si ejecuto las siguientes instrucciones?

# %%
list1[1] = 0
list1[2][0] = 0

# %%
list1[1] = 0
list1[2][0] = 0

# %%
strange_list

# %% [markdown]
# - ¿Qué es lo que sucedió? Las copias de listas generan un nuevo objeto, pero:
# - Para elementos **inmutables** (números, strings): no hay problema
# - Para elementos **mutables** (listas, diccionarios): ¡comparten la misma referencia!

# %% [markdown]
# # Ahora que sabemos un poco más de listas
# ## Retomamos el DESAFIO de las películas
# Nuestro desafío era:
#
# > Queremos procesar las duraciones de las películas argentinas candidatas al premio Oscar a película extrajera.
#
# Queremos saber:
# - ¿Cuál fue la duración promedio, en minutos?
# - ¿Cuántas películas duran más que el promedio, en minutos?

# %% [markdown]
# La solución planteada era:
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```

# %% [markdown]
# ## ⏩ Primer paso: generamos la lista con las duraciones
# Si no sabemos cuántas películas vamos a procesar, vamos a suponer que ingresamos una duración igual a 0 para finalizar el ingreso de datos.
#
# * ¿Cómo hacemos la iteración?
# * ¿Qué debemos hacer antes de guardar elementos en una lista?

# %% [markdown]
# ## ⏩ Segundo paso: calculamos el promedio
# * ¿Cómo se calcula el promedio?

# %% [markdown]
# ## ⏩  Tercer paso: calculamos cuántas duran más que el promedio
# * ¿Qué estructura permite recorrer y encontrarlas?

# %% [markdown]
# # 🎒 Tuplas
# > <span style="color:#cd7815">Son colecciones heterogéneas de datos ordenados.</span>
#
# > Se utiliza el caracter <span style="color:#cd7815">( )</span> para definir la tupla.

# %%
tuple0 = 1, 2 
tuple1 = (1, 2)
tuple2 = (1,)  # OJO con esto
tuple3 = ()
print(type(tuple0))
print(len(tuple2))

# %% [markdown]
# ## 🔧  Operaciones

# %% [markdown]
# * **len**(tuple0): retorna la cantidad de elementos en ambos casos.
# * **in**: retorna si un elemento pertenece o no a una tupla.
# * Se pueden concatenar **(+)** y repetir **(*)**.
# *  **count()**: cuenta ocurrencias.
# * **index()**: encuentra primera posición.

# %%
tupla = (1, 2, 3)

# Desempaquetado básico
a, b, c = tupla
print(a, b, c)  # 1 2 3

# %% [markdown]
# ## Similitudes con las listas
# - Se accede a los elementos de igual manera: usando **[]** (empezando desde cero)

# %%
my_tuple = (1, "dos", [3, "cuatro"], 5.5, True)
my_tuple

# %% [markdown]
# ## ¿Cuál es la diferencia con las listas?
#
# Veamos este ejemplo:

# %%
my_tuple[0] = 3

# %% [markdown]
# ## DIFERENCIA: <span style="color:#cd7815">las tuplas son INMUTABLES</span>
#
# - Su tamaño y los valores de las mismas NO pueden cambiar.

# %% [markdown]
# * ¿No puedo modificar ningún elemento de esta tupla?
# ```python
# my_tuple = (1, "dos", [3, "cuatro"], 5.5, True)
# ```
# * ¿Cuántos elementos tiene la tupla?

# %%
len(my_tuple)

# %%
my_tuple[2][0] = 4

# %% [markdown]
# ¿Cambió algún dato de la tupla?

# %%
my_tuple

# %% [markdown]
# # 🎒  Conjuntos
#
# > <span style="color:#cd7815">Un conjunto es una colección de datos heterogéna, **desordenada**, **NO indexada** y **sin elementos duplicados**.</span>
#
# > Se utiliza el caracter <span style="color:#cd7815">{elem1, elem2 }</span> para definir el conjunto.

# %%
my_set = {1, 2, 3, 4}
my_set = set()
not_set = {} #OJO con esto
type(not_set)

# %%
music = {"Linares Cardozo", "Carla Bruni", "La Santa Cecilia", "Gaby Moreno", "Katy Perry"}

our_band = set(("Panza", "Pastillas del Abuelo"))
foreigner_bands = set([ "Carla Bruni", "La Santa Cecilia"])

# %% [markdown]
# ¿Qué operación estamos haciendo?

# %% [markdown]
# ## ⏩Desafío : ¿cuántos caracteres diferentes tiene esta frase?

# %%
frase = '''Amelia Mary Earhart (Atchison, Kansas, 24 de julio de 1897-desaparecida el 2 de julio de 
1937 y declarada muerta el 5 de enero de 1939) fue una profesora, conferenciante y pionera de la 
aviación estadounidense'''

# %%
len(set(frase))

# %% [markdown]
# ## Similitud con las estructuras vistas
#
# - La función **len()** retorna la cantidad de elementos en ambos casos.
# - **in**: retorna si un elemento pertenece o no a un conjunto.

# %% [markdown]
# ## ¿Cuál es la característica principal?
#
# No contiene elementos repetidos

# %%
my_list = [1, 1, 2, 2, 2,  3, 3, 3]
my_set = set(my_list)
my_set

# %% [markdown]
# ¿Qué operaciones recuerdan con los conjuntos?

# %% [markdown]
# ## 🔧  Operaciones
# - Pensemos en las operaciones matemáticas sobre conjuntos:
#     - **|**: unión entre dos conjuntos.
#     - **&**: intersección entre dos conjuntos.
#     - **-**: diferencia de conjuntos.
# -  **add()**: agrega un elemento.
# -  **update()**: agrega mñas de un elemento.

# %% [markdown]
# ## Retomamos el DESAFIO de las películas con modificaciones
# Nuestro desafío ahora es:
#
# > Queremos procesar  las películas  latinoamericanas candidatas al Oscar y luego **por país** indicar cuáles duran más que el promedio.
#
# - ¿Cómo podemos almacenar los datos para acceder fácilmente por país?

# %%
pel_lat = [
    ("Argentina", "El secreto de sus ojos", 129),
    ("México", "Roma", 135),
    ("Chile", "Una mujer fantástica", 100),
    ("Brasil", "Central do Brasil", 113),
    ("México", "Amores perros", 154),
    ("Chile", "No", 118),
    ("Argentina", "Relatos salvajes", 122),
    ("Brasil", "Cidade de Deus", 130),
    ("Argentina", "La historia oficial", 112),
]

# %% [markdown]
# # 🎒   Diccionarios en Python
# > Es un conjunto **ordenado** de pares de datos: <span style="color:#cd7815">**clave:valor**</span> .
#
# > Se utiliza el caracter <span style="color:#cd7815">{ **clave:valor**}</span> para definir el diccionario.

# %%
my_dict1 = {'uno': 1}
my_dict2 = {} 
my_dict3 = dict()
type(my_dict1)

# %% [markdown]
# ### 🚨 No confundir

# %%
my_dict = {}
my_set = {1, 2, 3}

type(my_dict)

# %% [markdown]
# * Puedo utilizar esta estructura para organizar las películas por **país**

# %%
pel_lat = {    "Argentina": [
        ("El secreto de sus ojos", 129),
        ("Relatos salvajes", 122),
        ("La historia oficial", 112)
    ],
    "México": [
        ("Roma", 135),
        ("Amores perros", 154)
    ],
    "Chile": [
        ("Una mujer fantástica", 100),
        ("No", 118)
    ],
    "Brasil": [
        ("Central do Brasil",   113),
        ("Cidade de Deus", 130)
    ]
}

# %% [markdown]
# ### ¿Cómo accedo **directamente** a las películas de cada país?

# %%
pel_lat["México"]

# %% [markdown]
# ## Las claves deben ser únicas e inmutables
#
# - Las **claves** pueden ser cualquier tipo **inmutable**.
#     - Las cadenas y números siempre pueden ser claves.
#     - Las tuplas se pueden usar sólo si no tienen objetos mutables.

# %% [markdown]
# ### ⏩ Probar cuáles de las siguientes instrucciones dan error

# %%
#my_dic = {"uno":1}
#my_dic = {1: "uno"}
#my_dic = {[1,2]: "lista"}
#my_dic = {(1,2): "tupla"}
#my_dic = {([1],2): "tupla"}
#my_dic

# %% [markdown]
# ## Similitud con las estructuras vistas
# * **len()**: indica la cantidad de claves del diccionario.
# * **in**: retorna si existe o no la clave en el diccionario.
# *  **diccionario[clave]**: permite acceder al valor asociado a la **clave**.

# %% [markdown]
# ## 🔧  Operaciones
#
# * **dict[clave]** = valor: permite agregar una clave.
# * **dict.keys()**: devuelve todas las claves.
# * **dict.values()**: devuelve sólo los valores de todas las claves.
# * **dict.items()**: devuelve como tuplas todas las claves con su valor asociado.
